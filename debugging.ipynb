# %%
import pandas as pd

# %%
df = pd.read_csv(r"F:\finetunining sample\hello.csv")

# %%
df[['input_text','input_text_mod']]
# Out:
#                                               input_text  \
# 0      flowviewresponsestatemanager should call deleg...
# 1      javax.faces.viewstate hidden field resolves to...
# 2      flowfacescontext.newinstance should take into ...
# 3      portletexternalcontextimpl should mimic the be...
# 4               views are not inherited from parent flow
# ...                                                  ...
# 16168  npe when handling the empty namespace as a cus...
# 16169  concurrentmodificationexception in simplejdbcc...
# 16170  statementcreatorutils.setnull throws exception...
# 16171  @configurable beancurrentlyincreationexception...
# 16172                           junit 4.5 support broken
#
#                                           input_text_mod
# 0      flowviewresponsestatemanager should call deleg...
# 1      javax.faces.viewstate hidden field resolves to...
# 2      flowfacescontext.newinstance should take into ...
# ...

# %%
for i in df.index:
    print(df.iloc[i][''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\test_env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 for i in df.index:
# ----> 2     print(df[i])
#
# ...

# %%
val['input_text'].to_list()
# Out:
# ['javax.faces.viewstate hidden field resolves to spring webflow state id instead of outer faces state',
#  'views are not inherited from parent flow',
#  'split out jsf 2 specific methods from flowfacescontext for backwards compatibility with jsf 1.2',
#  'messagecontexterrors resolvemessagecodes',
#  'nullpointerexception in org.springframework.faces.ui.progressiveuicommand when the facelets included with mojarra 2.0.2 is enabled',
#  'problem with clustered sessions',
#  'swf2  spring3 portlets nosuchmethoderror portlet.flowhandleradapter.checkandprepare',
#  'hitting escape or close on a popup causes webflow to become out of sync',
#  'web flow first wants to resolve the model before even checking if a databinding should be done at all',
#  'org.springframework.js.resource.resourceservlet  an attempt to access a protected resource at dojoresourcesblank.html was disallowed.',
#  'filenameflowurlhandler does not implement createflowdefinitionurl',
# ...
